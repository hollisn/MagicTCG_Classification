# %% [markdown]
# ### Ingest
#
# Goal: Get all cards read in from JSON and saved as a pickle. Keep as much data as will be useful, drop the rest.

# %%
import numpy as np
import pandas as pd
import json
import re

# %% [markdown]
# To download all the cards run:

# %%
# import all magic cards ever printed, from web 14mb

# allsets = pd.read_json('http://mtgjson.com/json/AllSetsArray.json')
# allsets.info()

# %% [markdown]
# Else run this to load a locally stored file (and be nice to our kind friend's api)

# %%
# import all magic cards from file 

allsets = pd.read_json('data/AllSetsArray.json')
allsets.tail(2)
# Out:
#                    block                                            booster  \
# 185  Battle for Zendikar  [[rare, mythic rare], uncommon, uncommon, unco...
# 186                  NaN                                                NaN
#
#     border                                              cards code  \
# 185  black  [{u'layout': u'normal', u'name': u'Bane of Bal...  BFZ
# 186  black  [{u'layout': u'normal', u'name': u'Prairie Str...  EXP
#
#     gathererCode magicCardsInfoCode magicRaritiesCodes                  name  \
# 185          NaN                bfz                NaN   Battle for Zendikar
# 186          NaN                exp                NaN  Zendikar Expeditions
#
#     oldCode  onlineOnly releaseDate       type
# 185     NaN         NaN  2015-10-02  expansion
# 186     NaN         NaN  2015-10-02      promo

# %% [markdown]
# Top level dataframe is 186 rows of one set per row. Cards for that set are stored in the "cards" colum as another JSON array. Sets tend to have 200-350 cards in each.

# %%
# drop columns that are full of nan and/or junk

allsets = allsets.drop(['booster', 'gathererCode', 'magicCardsInfoCode', 
                        'magicCardsInfoCode', 'code',
                        'oldCode', 'onlineOnly', 'magicRaritiesCodes'
                        ], axis=1)

# %% [markdown]
# ### Grab the most recent set and check it out

# %%
# zoom in on cards from latest set, 'Battle for Zendikar'

zen = pd.read_json(json.dumps(allsets.cards[185]))

# add set name and date
zen['set'] = allsets.name[185]
zen['releaseDate'] = allsets.releaseDate[185]

zen.head(2)
# Out:
#           artist  cmc colors  \
# 0    Chase Stone    7    NaN
# 1  Todd Lockwood    5    NaN
#
#                                               flavor  \
# 0  The continent of Bala Ged was ravaged by massi...
# 1                                                NaN
#
#                                          id         imageName  layout  \
# 0  b2baccd791f5ada8bbd505f11bf81e70c8ea27ab  bane of bala ged  normal
# 1  cfff5e44e0263f10015fcf613b0f40065acf00b7     blight herder  normal
#
#    loyalty manaCost  multiverseid     ...        rarity              subtypes  \
# 0      NaN      {7}        401814     ...      Uncommon             [Eldrazi]
# 1      NaN      {5}        401819     ...          Rare  [Eldrazi, Processor]
#
#   supertypes                                               text toughness  \
# 0        NaN  Whenever Bane of Bala Ged attacks, defending p...         5
# 1        NaN  When you cast Blight Herder, you may put two c...         5
#
#                            type       types variations                  set  \
# 0            Creature — Eldrazi  [Creature]        NaN  Battle for Zendikar
# 1  Creature — Eldrazi Processor  [Creature]        NaN  Battle for Zendikar
#
#   releaseDate
# 0  2015-10-02
# 1  2015-10-02
#
# [2 rows x 23 columns]

# %%
# drop junk 
zen.drop(['id', 'layout', 'multiverseid', 'imageName', 'subtypes', 
          'supertypes', 'variations', 'loyalty', 'number'], 
         axis=1, inplace=True)

zen.head(2)
# Out:
#           artist  cmc colors  \
# 0    Chase Stone    7    NaN
# 1  Todd Lockwood    5    NaN
#
#                                               flavor manaCost  \
# 0  The continent of Bala Ged was ravaged by massi...      {7}
# 1                                                NaN      {5}
#
#                name power    rarity  \
# 0  Bane of Bala Ged     7  Uncommon
# 1     Blight Herder     4      Rare
#
#                                                 text toughness  \
# 0  Whenever Bane of Bala Ged attacks, defending p...         5
# 1  When you cast Blight Herder, you may put two c...         5
#
#                            type       types                  set releaseDate
# 0            Creature — Eldrazi  [Creature]  Battle for Zendikar  2015-10-02
# 1  Creature — Eldrazi Processor  [Creature]  Battle for Zendikar  2015-10-02

# %%
# grab the text from card 1

zen['text'][1]
# Out:
# u'When you cast Blight Herder, you may put two cards your opponents own from exile into their owners\' graveyards. If you do, put three 1/1 colorless Eldrazi Scion creature tokens onto the battlefield. They have "Sacrifice this creature: Add {1} to your mana pool."'

# %%
# fix errors

zen['text'].replace("\n" , " ", inplace=True, regex=True)
zen['text'].replace("\'" , "", inplace=True, regex=True)

zen['text'][1]
# Out:
# u'When you cast Blight Herder, you may put two cards your opponents own from exile into their owners graveyards. If you do, put three 1/1 colorless Eldrazi Scion creature tokens onto the battlefield. They have "Sacrifice this creature: Add {1} to your mana pool."'

# %% [markdown]
# ### More cards
#
# Now that we know everything words for one set, lets grab a bunch of sets and make one large table of cards. "Modern" is a major rules and format change the creators of the game enacted in 2003. It marks a turning point in the design, so, to start, we're only looking at cards after that date.

# %%
# slice sets for all of modern (arbritrary rules change date in 2003)

modern_sets = allsets[ (allsets['releaseDate'] >= '2003-07-28' ) ]
modern_sets = modern_sets.loc[modern_sets['type'].isin(['core', 'expansion'])]
modern_sets = modern_sets.loc[modern_sets['border'].isin(['white', 'black'])]

modern_sets.reset_index(inplace=True)
modern_sets
# Out:
#     index                block border  \
# 0      71                  NaN  white
# 1      72             Mirrodin  black
# 2      73             Mirrodin  black
# 3      74             Mirrodin  black
# 4      75             Kamigawa  black
# 5      77             Kamigawa  black
# 6      78             Kamigawa  black
# 7      79                  NaN  white
# 8      80              Ravnica  black
# 9      83              Ravnica  black
# 10     85              Ravnica  black
# 11     86              Ice Age  black
# 12     88          Time Spiral  black
# 13     89          Time Spiral  black
# 14     91          Time Spiral  black
# 15     94          Time Spiral  black
# 16     95                  NaN  black
# 17     98               Lorwyn  black
# 18    101               Lorwyn  black
# 19    103           Shadowmoor  black
# 20    105           Shadowmoor  black
# 21    109                Alara  black
# 22    111                Alara  black
# 23    113                Alara  black
# 24    114                  NaN  black
# 25    118             Zendikar  black
# 26    121             Zendikar  black
# 27    123             Zendikar  black
# 28    126                  NaN  black
# 29    129    Scars of Mirrodin  black
# 30    132    Scars of Mirrodin  black
# 31    134    Scars of Mirrodin  black
# 32    136                  NaN  black
# 33    139            Innistrad  black
# 34    141            Innistrad  black
# 35    143            Innistrad  black
# 36    145                  NaN  black
# 37    148    Return to Ravnica  black
# 38    150    Return to Ravnica  black
# 39    153    Return to Ravnica  black
# 40    155                  NaN  black
# 41    158               Theros  black
# 42    160               Theros  black
# 43    162               Theros  black
# 44    166                  NaN  black
# 45    170      Khans of Tarkir  black
# 46    177      Khans of Tarkir  black
# 47    179      Khans of Tarkir  black
# 48    182                  NaN  black
# 49    185  Battle for Zendikar  black
#
#                                                 cards  \
# 0   [{u'layout': u'normal', u'name': u'Abyssal Spe...
# 1   [{u'layout': u'normal', u'name': u'Æther Spell...
# 2   [{u'layout': u'normal', u'name': u'Æther Snap'...
# 3   [{u'layout': u'normal', u'name': u'Abuna's Cha...
# 4   [{u'layout': u'normal', u'name': u'Akki Avalan...
# 5   [{u'layout': u'normal', u'name': u'Akki Blizza...
# 6   [{u'layout': u'normal', u'name': u'Adamaro, Fi...
# 7   [{u'layout': u'normal', u'name': u'Adarkar Was...
# 8   [{u'layout': u'normal', u'name': u'Agrus Kos, ...
# 9   [{u'layout': u'normal', u'name': u'Absolver Th...
# 10  [{u'layout': u'normal', u'name': u'Æthermage's...
# 11  [{u'layout': u'normal', u'name': u'Adarkar Val...
# 12  [{u'layout': u'normal', u'name': u'Academy Rui...
# 13  [{u'layout': u'normal', u'name': u'Akroma, Ang...
# 14  [{u'layout': u'normal', u'name': u'Aeon Chroni...
# 15  [{u'layout': u'normal', u'name': u'Akroma's Me...
# 16  [{u'layout': u'normal', u'name': u'Abundance',...
# 17  [{u'layout': u'normal', u'name': u'Adder-Staff...
# 18  [{u'layout': u'normal', u'name': u'Ambassador ...
# 19  [{u'layout': u'normal', u'name': u'Advice from...
# 20  [{u'layout': u'normal', u'name': u'Aerie Ouphe...
# 21  [{u'layout': u'normal', u'name': u'Ad Nauseam'...
# 22  [{u'layout': u'normal', u'name': u'Absorb Vis'...
# 23  [{u'layout': u'normal', u'name': u'Anathemance...
# 24  [{u'layout': u'normal', u'name': u'Acidic Slim...
# 25  [{u'layout': u'normal', u'name': u'Adventuring...
# 26  [{u'layout': u'normal', u'name': u'Abyssal Per...
# 27  [{u'layout': u'normal', u'name': u'Affa Guard ...
# 28  [{u'layout': u'normal', u'name': u'Acidic Slim...
# 29  [{u'layout': u'normal', u'name': u'Abuna Acoly...
# 30  [{u'layout': u'normal', u'name': u'Accorder Pa...
# 31  [{u'layout': u'normal', u'name': u'Act of Aggr...
# 32  [{u'layout': u'normal', u'name': u'Acidic Slim...
# 33  [{u'layout': u'normal', u'name': u'Abattoir Gh...
# 34  [{u'layout': u'double-faced', u'name': u'Affli...
# 35  [{u'layout': u'normal', u'name': u'Abundant Gr...
# 36  [{u'layout': u'normal', u'name': u'Acidic Slim...
# 37  [{u'layout': u'normal', u'name': u'Abrupt Deca...
# 38  [{u'layout': u'normal', u'name': u'Act of Trea...
# 39  [{u'layout': u'normal', u'name': u'Advent of t...
# 40  [{u'layout': u'normal', u'name': u'Academy Rai...
# 41  [{u'layout': u'normal', u'name': u'Abhorrent O...
# 42  [{u'layout': u'normal', u'name': u'Acolyte's R...
# 43  [{u'layout': u'normal', u'name': u'Aegis of th...
# 44  [{u'layout': u'normal', u'name': u'Accursed Sp...
# 45  [{u'layout': u'normal', u'name': u'Abzan Battl...
# 46  [{u'layout': u'normal', u'name': u'Ugin, the S...
# 47  [{u'layout': u'normal', u'name': u'Scion of Ug...
# 48  [{u'layout': u'normal', u'name': u'Akroan Jail...
# 49  [{u'layout': u'normal', u'name': u'Bane of Bal...
#
#                          name releaseDate       type
# 0              Eighth Edition  2003-07-28       core
# 1                    Mirrodin  2003-10-02  expansion
# 2                   Darksteel  2004-02-06  expansion
# 3                  Fifth Dawn  2004-06-04  expansion
# 4       Champions of Kamigawa  2004-10-01  expansion
# 5       Betrayers of Kamigawa  2005-02-04  expansion
# 6         Saviors of Kamigawa  2005-06-03  expansion
# 7               Ninth Edition  2005-07-29       core
# 8     Ravnica: City of Guilds  2005-10-07  expansion
# 9                   Guildpact  2006-02-03  expansion
# 10                 Dissension  2006-05-05  expansion
# 11                   Coldsnap  2006-07-21  expansion
# 12                Time Spiral  2006-10-06  expansion
# 13  Time Spiral "Timeshifted"  2006-10-06  expansion
# 14               Planar Chaos  2007-02-02  expansion
# 15               Future Sight  2007-05-04  expansion
# 16              Tenth Edition  2007-07-13       core
# 17                     Lorwyn  2007-10-12  expansion
# 18                Morningtide  2008-02-01  expansion
# 19                 Shadowmoor  2008-05-02  expansion
# 20                   Eventide  2008-07-25  expansion
# 21            Shards of Alara  2008-10-03  expansion
# 22                    Conflux  2009-02-06  expansion
# 23               Alara Reborn  2009-04-30  expansion
# 24                 Magic 2010  2009-07-17       core
# 25                   Zendikar  2009-10-02  expansion
# 26                  Worldwake  2010-02-05  expansion
# 27        Rise of the Eldrazi  2010-04-23  expansion
# 28                 Magic 2011  2010-07-16       core
# 29          Scars of Mirrodin  2010-10-01  expansion
# 30          Mirrodin Besieged  2011-02-04  expansion
# 31               New Phyrexia  2011-05-13  expansion
# 32                 Magic 2012  2011-07-15       core
# 33                  Innistrad  2011-09-30  expansion
# 34             Dark Ascension  2012-02-03  expansion
# 35            Avacyn Restored  2012-05-04  expansion
# 36                 Magic 2013  2012-07-13       core
# 37          Return to Ravnica  2012-10-05  expansion
# 38                  Gatecrash  2013-02-01  expansion
# 39              Dragon's Maze  2013-05-03  expansion
# 40        Magic 2014 Core Set  2013-07-19       core
# 41                     Theros  2013-09-27  expansion
# 42           Born of the Gods  2014-02-07  expansion
# 43           Journey into Nyx  2014-05-02  expansion
# 44        Magic 2015 Core Set  2014-07-18       core
# 45            Khans of Tarkir  2014-09-26  expansion
# 46              Fate Reforged  2015-01-23  expansion
# 47          Dragons of Tarkir  2015-03-27  expansion
# 48              Magic Origins  2015-07-17       core
# 49        Battle for Zendikar  2015-10-02  expansion

# %%
# groups cards from sets into one data frame 

cards = None

for s in xrange(len(modern_sets)):
    print "Reading in set:", modern_sets.name[s]
    target = pd.read_json(json.dumps(modern_sets.cards[s]))
    
    # slice to just the good stuff 
    target = target[['artist', 'cmc', 'colors', 'flavor', 'manaCost', 'name', 
                    'power', 'rarity', 'text', 'toughness', 'type', 'types']]
    
    # add set name and date
    target['set'] = modern_sets.name[s]
    target['releaseDate'] = modern_sets.releaseDate[s]    
    
    # add to cards df 
    cards = pd.concat([cards, target])

# clean up errors
cards['text'].replace("\n" , " ", inplace=True, regex=True)
cards['text'].replace("\'" , "", inplace=True, regex=True)
cards['flavor'].replace("\n" , " ", inplace=True, regex=True)

print 
print cards.info(verbose=False)
# Out:
# Reading in set: Eighth Edition
# Reading in set: Mirrodin
# Reading in set: Darksteel
# Reading in set: Fifth Dawn
# Reading in set: Champions of Kamigawa
# Reading in set: Betrayers of Kamigawa
# Reading in set: Saviors of Kamigawa
# Reading in set: Ninth Edition
# Reading in set: Ravnica: City of Guilds
# Reading in set: Guildpact
# Reading in set: Dissension
# Reading in set: Coldsnap
# Reading in set: Time Spiral
# Reading in set: Time Spiral "Timeshifted"
# Reading in set: Planar Chaos
# Reading in set: Future Sight
# Reading in set: Tenth Edition
# Reading in set: Lorwyn
# Reading in set: Morningtide
# Reading in set: Shadowmoor
# Reading in set: Eventide
# Reading in set: Shards of Alara
# Reading in set: Conflux
# Reading in set: Alara Reborn
# Reading in set: Magic 2010
# Reading in set: Zendikar
# Reading in set: Worldwake
# Reading in set: Rise of the Eldrazi
# Reading in set: Magic 2011
# Reading in set: Scars of Mirrodin
# Reading in set: Mirrodin Besieged
# Reading in set: New Phyrexia
# Reading in set: Magic 2012
# Reading in set: Innistrad
# Reading in set: Dark Ascension
# Reading in set: Avacyn Restored
# Reading in set: Magic 2013
# Reading in set: Return to Ravnica
# Reading in set: Gatecrash
# Reading in set: Dragon's Maze
# Reading in set: Magic 2014 Core Set
# Reading in set: Theros
# Reading in set: Born of the Gods
# Reading in set: Journey into Nyx
# Reading in set: Magic 2015 Core Set
# Reading in set: Khans of Tarkir
# Reading in set: Fate Reforged
# Reading in set: Dragons of Tarkir
# Reading in set: Magic Origins
# Reading in set: Battle for Zendikar
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11502 entries, 0 to 298
# Columns: 14 entries, artist to releaseDate
# dtypes: float64(1), object(13)
# memory usage: 1.3+ MB
# None

# %% [markdown]
# This gives us 11502 cards
#
# but this is too many cards, included are promotional tokens that we do not want.

# %%
# filter out lands and tokens 

cards = cards.loc[cards['rarity'].isin(['Common', 'Uncommon', 'Rare', 
                                        'Mythic Rare'])]
cards.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10765 entries, 0 to 248
# Columns: 14 entries, artist to releaseDate
# dtypes: float64(1), object(13)
# memory usage: 1.2+ MB

# %% [markdown]
# This gives 10765 cards.
#
# Now the next problem is some cards do not have a color (artifacts) and some cards are multiple colors (gold, hybrid). Lets leave them out for now.

# %%
# only keep cards with a 'color' attribute
cards_no_nulls = cards[cards['colors'].notnull()]

# only keep cards with text
cards_no_nulls = cards_no_nulls[cards_no_nulls['text'].notnull()]

# only keep cards with a mana cost
cards_no_nulls = cards_no_nulls[cards_no_nulls['colors'].map(len) == 1]
cards_no_nulls.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7874 entries, 0 to 197
# Columns: 14 entries, artist to releaseDate
# dtypes: float64(1), object(13)
# memory usage: 922.7+ KB

# %%
# reset index and drop old index vals 

cards_no_nulls.reset_index(inplace=True)
cards_no_nulls.pop('index')
# cards_no_nulls.pop('level_0')
cards_no_nulls
# Out:
#                       artist  cmc   colors  \
# 0             Michael Sutfin    4  [Black]
# 1              Wayne England    5   [Blue]
# 2              Junko Taguchi    4  [Black]
# 3     Alex Horley-Orlandelli    4    [Red]
# 4          Melissa A. Benson    5  [White]
# 5               Marc Fishman    2  [White]
# 6            Donato Giancola    4   [Blue]
# 7              Paolo Parente    5  [White]
# 8                   Mark Zug    8  [White]
# 9               Justin Sweet    4  [White]
# 10       Christopher Moeller    4   [Blue]
# 11    Greg & Tim Hildebrandt    5  [White]
# 12                  Adam Rex    5   [Blue]
# 13      Edward P. Beard, Jr.    1  [Green]
# 14             Paolo Parente    3  [Green]
# 15    Alex Horley-Orlandelli    1    [Red]
# 16       Christopher Moeller    2  [White]
# 17             Todd Lockwood    5  [White]
# 18           Franz Vohwinkel    3    [Red]
# 19               Daren Bader    6    [Red]
# 20            Carl Critchlow    2  [Black]
# 21               Dave Dorman    4  [Black]
# 22    Jason Alexander Behnke    4    [Red]
# 23           Alan Rabinowitz    2   [Blue]
# 24           Andrew Robinson    5   [Blue]
# 25             Paolo Parente    4  [Green]
# 26          Christopher Rush    2  [Green]
# 27                Gary Leach    2    [Red]
# 28             Tony Szczudlo    3  [Black]
# 29                     Berry    3   [Blue]
# ...                      ...  ...      ...
# 7844           Yeong-Hao Han    4    [Red]
# 7845            Chris Rallis    4    [Red]
# 7846         Anthony Palumbo    2  [Green]
# 7847               Dan Scott    2  [Green]
# 7848            Lake Hurwitz    4  [Green]
# 7849          Eric Deschamps    6  [Green]
# 7850        Daniel Ljunggren    4  [Green]
# 7851                 Daarken    1  [Green]
# 7852           Willian Murai    3  [Green]
# 7853          Eric Deschamps    4  [Green]
# 7854             Wesley Burt    3  [Green]
# 7855           Lius Lasahido    6  [Green]
# 7856              Chris Rahn    6  [Green]
# 7857  Anastasia Ovchinnikova    2  [Green]
# 7858           Jama Jurabaev    7  [Green]
# 7859            Aaron Miller    2  [Green]
# 7860      Bastien L. Deharme    4  [Green]
# 7861           Kieran Yanner    3  [Green]
# 7862           Yeong-Hao Han    2  [Green]
# 7863        Daniel Ljunggren    1  [Green]
# 7864         Anna Steinbauer    2  [Green]
# 7865              Kev Walker    2  [Green]
# 7866       Magali Villeneuve    2  [Green]
# 7867        Daniel Ljunggren    2  [Green]
# 7868          Greg Opalinski    6  [Green]
# 7869             Wesley Burt    3  [Green]
# 7870  Anastasia Ovchinnikova    5  [Green]
# 7871            Matt Stewart    5  [Green]
# 7872          Tyler Jacobson    3  [Green]
# 7873           Vincent Proce    4  [Green]
#
#                                                  flavor      manaCost  \
# 0            To gaze under its hood is to invite death.     {2}{B}{B}
# 1     Pray that it doesn't seek the safety of your l...     {3}{U}{U}
# 2                        "Knowledge demands sacrifice."        {3}{B}
# 3               Just try taking this bull by the horns.        {3}{R}
# 4            A song of life soars over fields of blood.        {4}{W}
# 5     If only every message were as perfect as its b...        {1}{W}
# 6     "Words—so innocent and powerless are they, as ...     {2}{U}{U}
# 7     Knights fight for honor and mercenaries fight ...        {4}{W}
# 8                                                   NaN     {6}{W}{W}
# 9                                                   NaN        {3}{W}
# 10    The same spears that catch their food today wi...        {3}{U}
# 11    Just as each added feather steadies the wing, ...        {4}{W}
# 12    "To empty your mind is to fill your grave." —L...     {3}{U}{U}
# 13                                                  NaN           {G}
# 14    "There's never been a dwarven smith who could ...        {2}{G}
# 15                               Fire never dies alone.        {X}{R}
# 16                Even an enemy is a valuable resource.        {1}{W}
# 17    "Their eyes will shrivel and blacken before fa...     {3}{W}{W}
# 18    Heavy light flooded across the landscape, cloa...        {2}{R}
# 19    After their first encounter, the goblins named...        {5}{R}
# 20           Think of it as a butcher knife with wings.        {1}{B}
# 21    The bodies of its victims are the only tracks ...        {3}{B}
# 22    "When every reef is bared and every wave is du...        {3}{R}
# 23    "Returne from whence ye came. . . ." —Edmund S...        {U}{U}
# 24    In Mercadia City, loyalties extend only as far...     {3}{U}{U}
# 25    From a whisper to a roar, the call is heard by...     {2}{G}{G}
# 26    It keeps the upper reaches of the forest free ...        {1}{G}
# 27    In the warrior kingdom of Keld, the cats used ...        {1}{R}
# 28    A wall built from the bodies of the enemy will...     {1}{B}{B}
# 29    Though those who study are as many as the hair...        {2}{U}
# ...                                                 ...           ...
# 7844  Like a living organism, Zendikar rids itself o...        {3}{R}
# 7845  "A hedron holds magic for a thousand years—or ...        {3}{R}
# 7846  "They come because I call. They stay because I...        {1}{G}
# 7847                                                NaN        {1}{G}
# 7848  "I always thought the great insects of Tazeem ...        {3}{G}
# 7849                                                NaN     {4}{G}{G}
# 7850  "Zendikar has given us the weapons to wage war...        {3}{G}
# 7851              On Murasa, even the trees grow trees.           {G}
# 7852  "The land is not dead, merely sick. I will nur...        {2}{G}
# 7853  "If you're not prepared to fight, you'd best b...        {3}{G}
# 7854  "Zendikar will not surrender, and neither can ...        {2}{G}
# 7855  Her connection to the plane restored, Nissa fe...        {5}{G}
# 7856                                                NaN     {4}{G}{G}
# 7857  "The world was not hostile to us—we were benea...        {1}{G}
# 7858  "It might fight the Eldrazi, but don't mistake...  {4}{G}{G}{G}
# 7859  The elf's blade carved deep into the Eldrazi d...        {1}{G}
# 7860  "This world tires of its long occupation."—Nis...     {2}{G}{G}
# 7861                                                NaN        {2}{G}
# 7862  "If I die, feed me to a shambler. At least tha...        {1}{G}
# 7863  Eldrazi are not the leopard's preferred prey, ...           {G}
# 7864  "In my downtime I used to paint the vistas. No...        {1}{G}
# 7865  All of Zendikar's beings sense the upheaval th...        {1}{G}
# 7866  "Nissa is not the only one with a deep connect...        {1}{G}
# 7867  "As long as there is a single shred of life, t...        {1}{G}
# 7868  "My mount needs neither reins nor bridle. We b...        {5}{G}
# 7869  "In its time of hardship, all of Zendikar crie...        {2}{G}
# 7870  Her rallying cry reaches far beyond the Tajuru...     {3}{G}{G}
# 7871  It knows nothing of Eldrazi or Planeswalkers, ...        {4}{G}
# 7872                                                NaN     {1}{G}{G}
# 7873  "The elements understand better than anyone th...        {3}{G}
#
#                           name power       rarity  \
# 0              Abyssal Specter     2     Uncommon
# 1                Air Elemental     4     Uncommon
# 2              Ambition's Cost   NaN     Uncommon
# 3                 Anaba Shaman     2       Common
# 4               Angel of Mercy     3     Uncommon
# 5                 Angelic Page     1       Common
# 6                    Archivist     1         Rare
# 7               Ardent Militia     2     Uncommon
# 8               Avatar of Hope     4         Rare
# 9             Aven Cloudchaser     2       Common
# 10                 Aven Fisher     2       Common
# 11                  Aven Flock     2       Common
# 12            Balance of Power   NaN         Rare
# 13           Birds of Paradise     0         Rare
# 14            Blanchwood Armor   NaN     Uncommon
# 15                       Blaze   NaN     Uncommon
# 16            Blessed Reversal   NaN         Rare
# 17              Blinding Angel     2         Rare
# 18                  Blood Moon   NaN         Rare
# 19           Bloodshot Cyclops     4         Rare
# 20                     Bog Imp     1       Common
# 21                  Bog Wraith     3     Uncommon
# 22                        Boil   NaN     Uncommon
# 23                   Boomerang   NaN       Common
# 24                     Bribery   NaN         Rare
# 25            Call of the Wild   NaN         Rare
# 26               Canopy Spider     1       Common
# 27              Canyon Wildcat     2       Common
# 28                Carrion Wall     3     Uncommon
# 29                     Catalog   NaN       Common
# ...                        ...   ...          ...
# 7844         Volcanic Upheaval   NaN       Common
# 7845      Zada, Hedron Grinder     3         Rare
# 7846        Beastcaller Savant     1         Rare
# 7847              Earthen Arms   NaN       Common
# 7848              Giant Mantis     2       Common
# 7849     Greenwarden of Murasa     5  Mythic Rare
# 7850  Infuse with the Elements   NaN     Uncommon
# 7851            Jaddi Offshoot     0     Uncommon
# 7852          Lifespring Druid     2       Common
# 7853             Murasa Ranger     3     Uncommon
# 7854        Natural Connection   NaN       Common
# 7855           Nissa's Renewal   NaN         Rare
# 7856           Oran-Rief Hydra     5         Rare
# 7857         Oran-Rief Invoker     2       Common
# 7858            Plated Crusher     7     Uncommon
# 7859                   Plummet   NaN       Common
# 7860          Reclaiming Vines   NaN       Common
# 7861        Retreat to Kazandu   NaN     Uncommon
# 7862              Rot Shambler     1     Uncommon
# 7863            Scythe Leopard     1     Uncommon
# 7864            Seek the Wilds   NaN       Common
# 7865          Snapping Gnarlid     2       Common
# 7866           Swell of Growth   NaN       Common
# 7867            Sylvan Scrying   NaN     Uncommon
# 7868        Tajuru Beastmaster     5       Common
# 7869           Tajuru Stalwart     0       Common
# 7870          Tajuru Warcaller     2     Uncommon
# 7871        Territorial Baloth     4       Common
# 7872      Undergrowth Champion     2  Mythic Rare
# 7873         Woodland Wanderer     2         Rare
#
#                                                    text toughness  \
# 0     Flying Whenever Abyssal Specter deals damage t...         3
# 1                                                Flying         4
# 2             You draw three cards and you lose 3 life.       NaN
# 3     {R}, {T}: Anaba Shaman deals 1 damage to targe...         2
# 4     Flying When Angel of Mercy enters the battlefi...         3
# 5     Flying {T}: Target attacking or blocking creat...         1
# 6                                     {T}: Draw a card.         1
# 7                                             Vigilance         5
# 8     If you have 3 or less life, Avatar of Hope cos...         9
# 9     Flying (This creature cant be blocked except b...         2
# 10    Flying (This creature cant be blocked except b...         2
# 11    Flying (This creature cant be blocked except b...         3
# 12    If target opponent has more cards in hand than...       NaN
# 13    Flying {T}: Add one mana of any color to your ...         1
# 14    Enchant creature (Target a creature as you cas...       NaN
# 15    Blaze deals X damage to target creature or pla...       NaN
# 16     You gain 3 life for each creature attacking you.       NaN
# 17    Flying (This creature cant be blocked except b...         4
# 18                        Nonbasic lands are Mountains.       NaN
# 19    {T}, Sacrifice a creature: Bloodshot Cyclops d...         4
# 20    Flying (This creature cant be blocked except b...         1
# 21    Swampwalk (This creature cant be blocked as lo...         3
# 22                                 Destroy all Islands.       NaN
# 23          Return target permanent to its owners hand.       NaN
# 24    Search target opponents library for a creature...       NaN
# 25    {2}{G}{G}: Reveal the top card of your library...       NaN
# 26    Reach (This creature can block creatures with ...         3
# 27    Mountainwalk (This creature cant be blocked as...         1
# 28    Defender (This creature cant attack.) {1}{B}: ...         2
# 29                 Draw two cards, then discard a card.       NaN
# ...                                                 ...       ...
# 7844                               Destroy target land.       NaN
# 7845  Whenever you cast an instant or sorcery spell ...         3
# 7846  Haste {T}: Add one mana of any color to your m...         1
# 7847  Put two +1/+1 counters on target permanent. Aw...       NaN
# 7848  Reach (This creature can block creatures with ...         4
# 7849  When Greenwarden of Murasa enters the battlefi...         4
# 7850  Converge — Put X +1/+1 counters on target crea...       NaN
# 7851  Defender Landfall — Whenever a land enters the...         3
# 7852  {T}: Add one mana of any color to your mana pool.         1
# 7853  Landfall — Whenever a land enters the battlefi...         3
# 7854  Search your library for a basic land card, put...       NaN
# 7855  Search your library for up to three basic land...       NaN
# 7856  Trample Landfall — Whenever a land enters the ...         5
# 7857  {8}: Oran-Rief Invoker gets +5/+5 and gains tr...         2
# 7858                                  Trample, hexproof         6
# 7859               Destroy target creature with flying.       NaN
# 7860     Destroy target artifact, enchantment, or land.       NaN
# 7861  Landfall — Whenever a land enters the battlefi...       NaN
# 7862  Whenever another creature you control dies, pu...         1
# 7863  Landfall — Whenever a land enters the battlefi...         1
# 7864  Look at the top four cards of your library. Yo...       NaN
# 7865  Landfall — Whenever a land enters the battlefi...         2
# 7866  Target creature gets +2/+2 until end of turn. ...       NaN
# 7867  Search your library for a land card, reveal it...       NaN
# 7868  Rally — Whenever Tajuru Beastmaster or another...         5
# 7869  Converge — Tajuru Stalwart enters the battlefi...         1
# 7870  Rally — Whenever Tajuru Warcaller or another A...         1
# 7871  Landfall — Whenever a land enters the battlefi...         4
# 7872  If damage would be dealt to Undergrowth Champi...         2
# 7873  Vigilance, trample Converge — Woodland Wandere...         2
#
#                                   type          types                  set  \
# 0                   Creature — Specter     [Creature]       Eighth Edition
# 1                 Creature — Elemental     [Creature]       Eighth Edition
# 2                              Sorcery      [Sorcery]       Eighth Edition
# 3           Creature — Minotaur Shaman     [Creature]       Eighth Edition
# 4                     Creature — Angel     [Creature]       Eighth Edition
# 5              Creature — Angel Spirit     [Creature]       Eighth Edition
# 6              Creature — Human Wizard     [Creature]       Eighth Edition
# 7             Creature — Human Soldier     [Creature]       Eighth Edition
# 8                    Creature — Avatar     [Creature]       Eighth Edition
# 9              Creature — Bird Soldier     [Creature]       Eighth Edition
# 10             Creature — Bird Soldier     [Creature]       Eighth Edition
# 11             Creature — Bird Soldier     [Creature]       Eighth Edition
# 12                             Sorcery      [Sorcery]       Eighth Edition
# 13                     Creature — Bird     [Creature]       Eighth Edition
# 14                  Enchantment — Aura  [Enchantment]       Eighth Edition
# 15                             Sorcery      [Sorcery]       Eighth Edition
# 16                             Instant      [Instant]       Eighth Edition
# 17                    Creature — Angel     [Creature]       Eighth Edition
# 18                         Enchantment  [Enchantment]       Eighth Edition
# 19            Creature — Cyclops Giant     [Creature]       Eighth Edition
# 20                      Creature — Imp     [Creature]       Eighth Edition
# 21                   Creature — Wraith     [Creature]       Eighth Edition
# 22                             Instant      [Instant]       Eighth Edition
# 23                             Instant      [Instant]       Eighth Edition
# 24                             Sorcery      [Sorcery]       Eighth Edition
# 25                         Enchantment  [Enchantment]       Eighth Edition
# 26                   Creature — Spider     [Creature]       Eighth Edition
# 27                      Creature — Cat     [Creature]       Eighth Edition
# 28                     Creature — Wall     [Creature]       Eighth Edition
# 29                             Instant      [Instant]       Eighth Edition
# ...                                ...            ...                  ...
# 7844                           Instant      [Instant]  Battle for Zendikar
# 7845  Legendary Creature — Goblin Ally     [Creature]  Battle for Zendikar
# 7846        Creature — Elf Shaman Ally     [Creature]  Battle for Zendikar
# 7847                           Sorcery      [Sorcery]  Battle for Zendikar
# 7848                 Creature — Insect     [Creature]  Battle for Zendikar
# 7849              Creature — Elemental     [Creature]  Battle for Zendikar
# 7850                           Instant      [Instant]  Battle for Zendikar
# 7851                  Creature — Plant     [Creature]  Battle for Zendikar
# 7852              Creature — Elf Druid     [Creature]  Battle for Zendikar
# 7853          Creature — Human Warrior     [Creature]  Battle for Zendikar
# 7854                           Instant      [Instant]  Battle for Zendikar
# 7855                           Sorcery      [Sorcery]  Battle for Zendikar
# 7856                  Creature — Hydra     [Creature]  Battle for Zendikar
# 7857           Creature — Human Shaman     [Creature]  Battle for Zendikar
# 7858                  Creature — Beast     [Creature]  Battle for Zendikar
# 7859                           Instant      [Instant]  Battle for Zendikar
# 7860                           Sorcery      [Sorcery]  Battle for Zendikar
# 7861                       Enchantment  [Enchantment]  Battle for Zendikar
# 7862                 Creature — Fungus     [Creature]  Battle for Zendikar
# 7863                    Creature — Cat     [Creature]  Battle for Zendikar
# 7864                           Sorcery      [Sorcery]  Battle for Zendikar
# 7865                  Creature — Beast     [Creature]  Battle for Zendikar
# 7866                           Instant      [Instant]  Battle for Zendikar
# 7867                           Sorcery      [Sorcery]  Battle for Zendikar
# 7868       Creature — Elf Warrior Ally     [Creature]  Battle for Zendikar
# 7869         Creature — Elf Scout Ally     [Creature]  Battle for Zendikar
# 7870       Creature — Elf Warrior Ally     [Creature]  Battle for Zendikar
# 7871                  Creature — Beast     [Creature]  Battle for Zendikar
# 7872              Creature — Elemental     [Creature]  Battle for Zendikar
# 7873              Creature — Elemental     [Creature]  Battle for Zendikar
#
#      releaseDate
# 0     2003-07-28
# 1     2003-07-28
# 2     2003-07-28
# 3     2003-07-28
# 4     2003-07-28
# 5     2003-07-28
# 6     2003-07-28
# 7     2003-07-28
# 8     2003-07-28
# 9     2003-07-28
# 10    2003-07-28
# 11    2003-07-28
# 12    2003-07-28
# 13    2003-07-28
# 14    2003-07-28
# 15    2003-07-28
# 16    2003-07-28
# 17    2003-07-28
# 18    2003-07-28
# 19    2003-07-28
# 20    2003-07-28
# 21    2003-07-28
# 22    2003-07-28
# 23    2003-07-28
# 24    2003-07-28
# 25    2003-07-28
# 26    2003-07-28
# 27    2003-07-28
# 28    2003-07-28
# 29    2003-07-28
# ...          ...
# 7844  2015-10-02
# 7845  2015-10-02
# 7846  2015-10-02
# 7847  2015-10-02
# 7848  2015-10-02
# 7849  2015-10-02
# 7850  2015-10-02
# 7851  2015-10-02
# 7852  2015-10-02
# 7853  2015-10-02
# 7854  2015-10-02
# 7855  2015-10-02
# 7856  2015-10-02
# 7857  2015-10-02
# 7858  2015-10-02
# 7859  2015-10-02
# 7860  2015-10-02
# 7861  2015-10-02
# 7862  2015-10-02
# 7863  2015-10-02
# 7864  2015-10-02
# 7865  2015-10-02
# 7866  2015-10-02
# 7867  2015-10-02
# 7868  2015-10-02
# 7869  2015-10-02
# 7870  2015-10-02
# 7871  2015-10-02
# 7872  2015-10-02
# 7873  2015-10-02
#
# [7874 rows x 14 columns]

# %%
# datamunge to get "color" out of a list format

def nolist(x):
    return x[0]

cards_no_nulls['colors'] = cards_no_nulls['colors'].apply(nolist)

# %% [markdown]
# Some cards have resource symbols in their text with their color. This might give a classifier an unfair advantage.

# %%
# remove resource symbols from one card 

a = cards_no_nulls.text[3]
re.sub("{[A-Z]}" , "{1}", a)
# Out:
# u'{1}, {1}: Anaba Shaman deals 1 damage to target creature or player.'

# %%
# remove resource symbols from all cards 

def tap(x):
    return re.sub("{T}" , "Tap ", x)

def nomana(x):
    return re.sub("{[A-Z]}" , "{1}", x)

cards_no_nulls.text = cards_no_nulls.text.apply(tap)
cards_no_nulls.text = cards_no_nulls.text.apply(nomana)

# %%
cards_no_nulls.text
# Out:
# 0       Flying Whenever Abyssal Specter deals damage t...
# 1                                                  Flying
# 2               You draw three cards and you lose 3 life.
# 3       {1}, Tap : Anaba Shaman deals 1 damage to targ...
# 4       Flying When Angel of Mercy enters the battlefi...
# 5       Flying Tap : Target attacking or blocking crea...
# 6                                      Tap : Draw a card.
# 7                                               Vigilance
# 8       If you have 3 or less life, Avatar of Hope cos...
# 9       Flying (This creature cant be blocked except b...
# 10      Flying (This creature cant be blocked except b...
# 11      Flying (This creature cant be blocked except b...
# 12      If target opponent has more cards in hand than...
# 13      Flying Tap : Add one mana of any color to your...
# 14      Enchant creature (Target a creature as you cas...
# 15      Blaze deals X damage to target creature or pla...
# 16       You gain 3 life for each creature attacking you.
# 17      Flying (This creature cant be blocked except b...
# 18                          Nonbasic lands are Mountains.
# 19      Tap , Sacrifice a creature: Bloodshot Cyclops ...
# 20      Flying (This creature cant be blocked except b...
# 21      Swampwalk (This creature cant be blocked as lo...
# 22                                   Destroy all Islands.
# 23            Return target permanent to its owners hand.
# 24      Search target opponents library for a creature...
# 25      {2}{1}{1}: Reveal the top card of your library...
# 26      Reach (This creature can block creatures with ...
# 27      Mountainwalk (This creature cant be blocked as...
# 28      Defender (This creature cant attack.) {1}{1}: ...
# 29                   Draw two cards, then discard a card.
#                               ...
# 7844                                 Destroy target land.
# 7845    Whenever you cast an instant or sorcery spell ...
# 7846    Haste Tap : Add one mana of any color to your ...
# 7847    Put two +1/+1 counters on target permanent. Aw...
# 7848    Reach (This creature can block creatures with ...
# 7849    When Greenwarden of Murasa enters the battlefi...
# 7850    Converge — Put X +1/+1 counters on target crea...
# 7851    Defender Landfall — Whenever a land enters the...
# 7852    Tap : Add one mana of any color to your mana p...
# 7853    Landfall — Whenever a land enters the battlefi...
# 7854    Search your library for a basic land card, put...
# 7855    Search your library for up to three basic land...
# 7856    Trample Landfall — Whenever a land enters the ...
# 7857    {8}: Oran-Rief Invoker gets +5/+5 and gains tr...
# 7858                                    Trample, hexproof
# 7859                 Destroy target creature with flying.
# 7860       Destroy target artifact, enchantment, or land.
# 7861    Landfall — Whenever a land enters the battlefi...
# 7862    Whenever another creature you control dies, pu...
# 7863    Landfall — Whenever a land enters the battlefi...
# 7864    Look at the top four cards of your library. Yo...
# 7865    Landfall — Whenever a land enters the battlefi...
# 7866    Target creature gets +2/+2 until end of turn. ...
# 7867    Search your library for a land card, reveal it...
# 7868    Rally — Whenever Tajuru Beastmaster or another...
# 7869    Converge — Tajuru Stalwart enters the battlefi...
# 7870    Rally — Whenever Tajuru Warcaller or another A...
# 7871    Landfall — Whenever a land enters the battlefi...
# 7872    If damage would be dealt to Undergrowth Champi...
# 7873    Vigilance, trample Converge — Woodland Wandere...
# Name: text, dtype: object

# %%
# store to disk

# cards_no_nulls.reset_index(inplace=True)
# cards_no_nulls.pop('index')

cards_no_nulls.to_pickle('data/cards_modern.pkl')

# %% [markdown]
# Some cards have their name in the text, names have no predictive ability and could only lead to overfitting.

# %%
# remove name from one card 

re.sub(cards_no_nulls.name[3] , "This", cards_no_nulls.text[3] )
# Out:
# u'{1}, Tap : This deals 1 damage to target creature or player.'

# %%
# remove card names from all cards  

import time

t0 = time.time()

for i in xrange(len(cards_no_nulls)):
    cards_no_nulls['text'][i] = re.sub(cards_no_nulls['name'][i] , "This", cards_no_nulls['text'][i]) 

t1 = time.time()

print round((t1-t0)/60, 2), "minutes"
cards_no_nulls.text
# Out:
# 9.96 minutes
# C:\Users\HN\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0       Flying Whenever This deals damage to a player,...
# 1                                                  Flying
# 2               You draw three cards and you lose 3 life.
# 3       {1}, Tap : This deals 1 damage to target creat...
# 4       Flying When This enters the battlefield, you g...
# 5       Flying Tap : Target attacking or blocking crea...
# 6                                      Tap : Draw a card.
# 7                                               Vigilance
# 8       If you have 3 or less life, This costs {6} les...
# 9       Flying (This creature cant be blocked except b...
# 10      Flying (This creature cant be blocked except b...
# 11      Flying (This creature cant be blocked except b...
# 12      If target opponent has more cards in hand than...
# 13      Flying Tap : Add one mana of any color to your...
# 14      Enchant creature (Target a creature as you cas...
# 15      This deals X damage to target creature or player.
# 16       You gain 3 life for each creature attacking you.
# 17      Flying (This creature cant be blocked except b...
# 18                          Nonbasic lands are Mountains.
# 19      Tap , Sacrifice a creature: This deals damage ...
# 20      Flying (This creature cant be blocked except b...
# 21      Swampwalk (This creature cant be blocked as lo...
# 22                                   Destroy all Islands.
# 23            Return target permanent to its owners hand.
# 24      Search target opponents library for a creature...
# 25      {2}{1}{1}: Reveal the top card of your library...
# 26      Reach (This creature can block creatures with ...
# 27      Mountainwalk (This creature cant be blocked as...
# 28      Defender (This creature cant attack.) {1}{1}: ...
# 29                   Draw two cards, then discard a card.
#                               ...
# 7844                                 Destroy target land.
# 7845    Whenever you cast an instant or sorcery spell ...
# 7846    Haste Tap : Add one mana of any color to your ...
# 7847    Put two +1/+1 counters on target permanent. Aw...
# 7848    Reach (This creature can block creatures with ...
# 7849    When This enters the battlefield, you may retu...
# 7850    Converge — Put X +1/+1 counters on target crea...
# 7851    Defender Landfall — Whenever a land enters the...
# 7852    Tap : Add one mana of any color to your mana p...
# 7853    Landfall — Whenever a land enters the battlefi...
# 7854    Search your library for a basic land card, put...
# 7855    Search your library for up to three basic land...
# 7856    Trample Landfall — Whenever a land enters the ...
# 7857    {8}: This gets +5/+5 and gains trample until e...
# 7858                                    Trample, hexproof
# 7859                 Destroy target creature with flying.
# 7860       Destroy target artifact, enchantment, or land.
# 7861    Landfall — Whenever a land enters the battlefi...
# 7862    Whenever another creature you control dies, pu...
# 7863    Landfall — Whenever a land enters the battlefi...
# 7864    Look at the top four cards of your library. Yo...
# 7865    Landfall — Whenever a land enters the battlefi...
# 7866    Target creature gets +2/+2 until end of turn. ...
# 7867    Search your library for a land card, reveal it...
# 7868    Rally — Whenever This or another Ally enters t...
# 7869    Converge — This enters the battlefield with a ...
# 7870    Rally — Whenever This or another Ally enters t...
# 7871    Landfall — Whenever a land enters the battlefi...
# 7872    If damage would be dealt to This while it has ...
# 7873    Vigilance, trample Converge — This enters the ...
# Name: text, dtype: object

# %%
# store to disk

# cards_no_nulls.reset_index(inplace=True)
# cards_no_nulls.pop('index')

cards_no_nulls.to_pickle('data/cards_modern_no_name.pkl')

# %% [markdown]
# Some cards have parentheses explaining what a rules term means. All this text is redundanct and could only mislead a classifer.

# %%
# remove helper text from one card 

a = cards_no_nulls.text[9]
re.sub('\([^)]*\)' , "", a)
# Out:
# u'Flying  When This enters the battlefield, destroy target enchantment.'

# %%
# remove helper text 

def hardmode(x):
    return re.sub('\([^)]*\)' , "", x)

cards_no_nulls.text = cards_no_nulls.text.apply(hardmode)

# %%
# store to disk

cards_no_nulls.to_pickle('data/5color_modern_no_name_hardmode.pkl')

# %% [markdown]
# ### New DF with all modern cards

# %%
# groups all modern cards of all colors from sets into one data frame 

cards = None

for s in xrange(len(modern_sets)):
    print "Reading in set:", modern_sets.name[s]
    target = pd.read_json(json.dumps(modern_sets.cards[s]))
    
    # slice to just the good stuff 
    target = target[['artist', 'cmc', 'colors', 'flavor', 'manaCost', 'name', 
                    'power', 'rarity', 'text', 'toughness', 'type', 'types']]
    
    # add set name and date
    target['set'] = modern_sets.name[s]
    target['releaseDate'] = modern_sets.releaseDate[s]    
    
    # add to cards df 
    cards = pd.concat([cards, target])

# clean up errors
cards['text'].replace("\n" , " ", inplace=True, regex=True)
cards['text'].replace("\'" , "", inplace=True, regex=True)

print 
print cards.info(verbose=False)

# drop tokens 
cards_no_nulls = cards.loc[cards['rarity'].isin(['Common', 'Uncommon', 
                                                 'Rare', 'Mythic Rare'])]

# only keep cards with text
cards_no_nulls = cards_no_nulls[cards_no_nulls['text'].notnull()]

# save the "tap" symbol
cards_no_nulls.text = cards_no_nulls.text.apply(tap)

# flatten all resource symbols from all cards 
cards_no_nulls.text = cards_no_nulls.text.apply(nomana)

# remove helper text 
cards_no_nulls.text = cards_no_nulls.text.apply(hardmode)

# reset index
cards_no_nulls.reset_index(inplace=True)
cards_no_nulls.pop('index')

print "Done!"
cards_no_nulls.info()
# Out:
# Reading in set: Eighth Edition
# Reading in set: Mirrodin
# Reading in set: Darksteel
# Reading in set: Fifth Dawn
# Reading in set: Champions of Kamigawa
# Reading in set: Betrayers of Kamigawa
# Reading in set: Saviors of Kamigawa
# Reading in set: Ninth Edition
# Reading in set: Ravnica: City of Guilds
# Reading in set: Guildpact
# Reading in set: Dissension
# Reading in set: Coldsnap
# Reading in set: Time Spiral
# Reading in set: Time Spiral "Timeshifted"
# Reading in set: Planar Chaos
# Reading in set: Future Sight
# Reading in set: Tenth Edition
# Reading in set: Lorwyn
# Reading in set: Morningtide
# Reading in set: Shadowmoor
# Reading in set: Eventide
# Reading in set: Shards of Alara
# Reading in set: Conflux
# Reading in set: Alara Reborn
# Reading in set: Magic 2010
# Reading in set: Zendikar
# Reading in set: Worldwake
# Reading in set: Rise of the Eldrazi
# Reading in set: Magic 2011
# Reading in set: Scars of Mirrodin
# Reading in set: Mirrodin Besieged
# Reading in set: New Phyrexia
# Reading in set: Magic 2012
# Reading in set: Innistrad
# Reading in set: Dark Ascension
# Reading in set: Avacyn Restored
# Reading in set: Magic 2013
# Reading in set: Return to Ravnica
# Reading in set: Gatecrash
# Reading in set: Dragon's Maze
# Reading in set: Magic 2014 Core Set
# Reading in set: Theros
# Reading in set: Born of the Gods
# Reading in set: Journey into Nyx
# Reading in set: Magic 2015 Core Set
# Reading in set: Khans of Tarkir
# Reading in set: Fate Reforged
# Reading in set: Dragons of Tarkir
# Reading in set: Magic Origins
# Reading in set: Battle for Zendikar
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11502 entries, 0 to 298
# Columns: 14 entries, artist to releaseDate
# dtypes: float64(1), object(13)
# memory usage: 1.3+ MB
# None
# Done!
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10521 entries, 0 to 10520
# Data columns (total 14 columns):
# artist         10521 non-null object
# cmc            10066 non-null float64
# colors         8965 non-null object
# flavor         7216 non-null object
# manaCost       10066 non-null object
# name           10521 non-null object
# power          5452 non-null object
# rarity         10521 non-null object
# text           10521 non-null object
# toughness      5452 non-null object
# type           10521 non-null object
# types          10521 non-null object
# set            10521 non-null object
# releaseDate    10521 non-null object
# dtypes: float64(1), object(13)
# memory usage: 1.2+ MB

# %%
# store to disk

cards_no_nulls.to_pickle('data/all_cards_modern_no_name_hardmode.pkl')
